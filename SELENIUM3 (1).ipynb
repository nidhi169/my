# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from bs4 import BeautifulSoup
import requests
import re

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %% [markdown]
# # 1.

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/"
driver.get(url)

# %%
search_button = driver.find_element_by_xpath('//a[@class="external text"]')       
search_button.click()

# %%
search = driver.find_element_by_xpath('//a[@title="List of most-viewed YouTube videos"]')       
search.click()

# %%
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
rank=driver.find_elements_by_xpath("//td[@align='center']")
for i in rank:
    if i.text is None :
        Rank.append("--") 
    else:
        Rank.append(i.text)
Rank
# Out:
# ['1.',
#  '8.98',
#  '[B]',
#  '2.',
#  '7.45',
#  '[C]',
#  '3.',
#  '5.56',
#  '[D]',
#  '4.',
#  '5.39',
#  '[E]',
#  '5.',
#  '5.18',
#  '[F]',
#  '6.',
#  '4.44',
#  '[G]',
#  '7.',
#  '4.31',
#  '[H]',
#  '8.',
#  '4.26',
#  '[I]',
#  '9.',
#  '4.23',
#  '[J]',
#  '10.',
#  '4.12',
#  '[K]',
#  '11.',
#  '3.99',
#  '12.',
#  '3.51',
#  '13.',
#  '3.46',
#  '14.',
#  '3.45',
#  '15.',
#  '3.39',
#  '16.',
#  '3.34',
#  '17.',
#  '3.29',
#  '18.',
#  '3.15',
#  '19.',
#  '3.10',
#  '20.',
#  '3.10',
#  '21.',
#  '3.07',
#  '22.',
#  '3.07',
#  '23.',
#  '3.06',
#  '24.',
#  '3.06',
#  '25.',
#  '3.03',
#  '26.',
#  '2.94',
#  '27.',
#  '2.90',
#  '28.',
#  '2.88',
#  '29.',
#  '2.88',
#  '30.',
#  '2.85',
#  '',
#  '',
#  '[118]',
#  '[P]',
#  '[28]',
#  '[35]',
#  '[Q]',
#  '[119]',
#  '[R]',
#  '93',
#  '[122]',
#  '[S]',
#  '171',
#  '[125]',
#  '176',
#  '[126]',
#  '289',
#  '[129]',
#  '124',
#  '[130]',
#  '14',
#  '[132]',
#  '[T]',
#  '[135]',
#  '[U]',
#  '68',
# ...

# %%
name=driver.find_elements_by_xpath("//a[@class='mw-redirect']")
for i in name:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)
Name
# Out:
# ['music videos',
#  'Baby Shark Dance',
#  'Baby Shark Dance',
#  'Baby Shark Dance',
#  'Cocomelon – Nursery Rhymes',
#  'Cocomelon – Nursery Rhymes',
#  'Cocomelon – Nursery Rhymes',
#  'The Gummy Bear Song',
#  'Fueled By Ramen',
#  'The Gummy Bear Song',
#  'Osito Gominola – Full Spanish Version – The Gummy Bear Song',
#  'Baby Shark Dance',
#  'Closer',
#  'Cocomelon – Nursery Rhymes',
#  'Cocomelon – Nursery Rhymes',
#  'Baby Shark Dance',
#  'List of most-viewed online trailers in the first 24 hours',
#  'regional restrictions',
#  'regional restrictions',
#  'Wired',
#  '',
#  '']

# %%
artist=driver.find_elements_by_xpath("//a[@title='Pinkfong Kids Songs & Stories']")
for i in artist:
    if i.text is None :
        Artist.append("--") 
    else:
        Artist.append(i.text)
Artist
# Out:
# []

# %%
date=driver.find_elements_by_xpath("//td[@align='right']")
for i in date:
    if i.text is None :
        Upload_date.append("--") 
    else:
        Upload_date.append(i.text)

# %%
view=driver.find_elements_by_xpath("//td[@align='Views']")
for i in view:
    if i.text is None :
        Views.append("--") 
    else:
        Views.append(i.text)

# %%
a=({'Rank':rank,
                     'Name':name,
                     'Upload_date':date,
                     'Artist':artist,
                     'Views':view})

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()

# %%
df.head(1)
# Out:
#                                                 Rank  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                                 Name  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                          Upload_date Artist Views
# 0  <selenium.webdriver.remote.webelement.WebEleme...   None  None

# %% [markdown]
# # 2.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
# PATH = "C:\Program Files (x86)\chromedriver.exe"
# from selenium import webdriver 
# driver = webdriver.Chrome(PATH)
# driver.get("https://www.bcci.tv/")

# %%
url = "https://www.bcci.tv/"
driver.get(url)

# %%
international = driver.find_element_by_xpath('//div[@class="navigation__drop-down drop-down drop-down--reveal-on-hover"]')       
international.click()

# %%
fixtures = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[2]/nav/ul/li[1]/div[2]/div/ul/li[1]/a')
fixtures.click()

# %%
rank = []
for i in driver.find_elements_by_xpath('//strong[@class="fixture__name fixture__name--with-margin"]'):
    rank.append(i.text)

# %%
date = []
for i in driver.find_elements_by_xpath('//span[@class="fixture__date"]'):
    date.append(i.text)

# %%
month = []
for i in driver.find_elements_by_xpath('//span[@class="fixture__month"]'):
    month.append(i.text)

# %%
time = []
for i in driver.find_elements_by_xpath('//span[@class="fixture__time"]'):
    time.append(i.text)

# %%
series = []
for i in driver.find_elements_by_xpath('//div[@class="fixture__teams"]'):
    series.append(i.text)

# %%
import pandas as pd 
df = pd.DataFrame({'Rank':rank,'Date':date,'Month':month,'Time':time,'Series':series})

# %%
df
# Out:
#        Rank Date      Month       Time               Series
# 0   3rd ODI   23       JULY  15:00 IST  SRI LANKA\nv\nINDIA
# 1  1st T20I   25       JULY  20:00 IST  SRI LANKA\nv\nINDIA
# 2  2nd T20I   27       JULY  20:00 IST  SRI LANKA\nv\nINDIA
# 3  3rd T20I   29       JULY  20:00 IST  SRI LANKA\nv\nINDIA
# 4  1st Test   04     AUGUST  15:30 IST    ENGLAND\nv\nINDIA
# 5  2nd Test   12     AUGUST  15:30 IST    ENGLAND\nv\nINDIA
# 6  3rd Test   25     AUGUST  15:30 IST    ENGLAND\nv\nINDIA
# 7  4th Test   02  SEPTEMBER  15:30 IST    ENGLAND\nv\nINDIA
# 8  5th Test   10  SEPTEMBER  15:30 IST    ENGLAND\nv\nINDIA

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
title=driver.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']")
for i in title:
    if i.text is None :
        Match_title.append("--") 
    else:
        Match_title.append(i.text)

# %%
Match_title
# Out:
# ['3rd ODI',
#  '1st T20I',
#  '2nd T20I',
#  '3rd T20I',
#  '1st Test',
#  '2nd Test',
#  '3rd Test',
#  '4th Test',
#  '5th Test']

# %%
series=driver.find_elements_by_xpath("//div[@class='fixture__teams']")
for i in series:
    if i.text is None :
        Series.append("--") 
    else:
        Series.append(i.text)

# %%
Series
# Out:
# ['SRI LANKA\nv\nINDIA',
#  'SRI LANKA\nv\nINDIA',
#  'SRI LANKA\nv\nINDIA',
#  'SRI LANKA\nv\nINDIA',
#  'ENGLAND\nv\nINDIA',
#  'ENGLAND\nv\nINDIA',
#  'ENGLAND\nv\nINDIA',
#  'ENGLAND\nv\nINDIA',
#  'ENGLAND\nv\nINDIA']

# %%
place=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']")
for i in place:
    if i.text is None :
        Place.append("--") 
    else:
        Place.append(i.text)

# %%
Place
# Out:
# ['3rd ODI\nR Premadasa Stadium, Colombo',
#  '1st T20I\nR Premadasa Stadium, Colombo',
#  '2nd T20I\nR Premadasa Stadium, Colombo',
#  '3rd T20I\nR Premadasa Stadium, Colombo',
#  '1st Test\nTrent Bridge, Nottingham',
#  "2nd Test\nLord's, London",
#  '3rd Test\nHeadingley, Leeds',
#  '4th Test\nThe Oval, London',
#  '5th Test\nOld Trafford, Manchester']

# %%
date=driver.find_elements_by_xpath("//span[@class='fixture__date']")
for i in date:
    if i.text is None :
        Date.append("--") 
    else:
        Date.append(i.text)

# %%
Date
# Out:
# ['23', '25', '27', '29', '04', '12', '25', '02', '10']

# %%
month=driver.find_elements_by_xpath("//span[@class='fixture__month']")
Month=[]
for i in month:
    if i.text is None :
        Month.append("--") 
    else:
        Month.append(i.text)

# %%
Month
# Out:
# ['JULY',
#  'JULY',
#  'JULY',
#  'JULY',
#  'AUGUST',
#  'AUGUST',
#  'AUGUST',
#  'SEPTEMBER',
#  'SEPTEMBER']

# %%
time=driver.find_elements_by_xpath("//span[@class='fixture__time']")
for i in time:
    if i.text is None :
        Time.append("--") 
    else:
        Time.append(i.text)

# %%
Time
# Out:
# ['15:00 IST',
#  '20:00 IST',
#  '20:00 IST',
#  '20:00 IST',
#  '15:30 IST',
#  '15:30 IST',
#  '15:30 IST',
#  '15:30 IST',
#  '15:30 IST']

# %%
import pandas as pd 
df = pd.DataFrame({'Match_title': title,
   'Series':series,
   'Place':place,
   'Date':date,
   'Month':month,
   'Time':time})

# %%
df.head(5)
# Out:
#                                          Match_title  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# 4  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                               Series  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# 4  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                                Place  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %% [markdown]
# # 3.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://www.guru99.com/"
driver.get(url)

# %% [markdown]
# # 4.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "http://statisticstimes.com/"
driver.get(url)

# %%
economy = driver.find_element_by_xpath('//button[@class="dropbtn"]')       
economy.click()

# %% [markdown]
# # 5.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://github.com/"
driver.get(url)

# %% [markdown]
# # 6.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://www.billboard.com/"
driver.get(url)

# %%
chart= driver.find_element_by_xpath("//a[@class='header__subnav__link text--uppercase font--semi-bold']")
chart.click()

# %%
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
name=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
for i in name:
    if i.text is None:
        Song_name.append('--')
    else:
        Song_name.append(i.text)

# %%
Song_name
# Out:
# ['Permission To Dance',
#  'Good 4 U',
#  'Stay',
#  'Levitating',
#  'Kiss Me More',
#  'Bad Habits',
#  'Butter',
#  'Montero (Call Me By Your Name)',
#  'Save Your Tears',
#  'Deja Vu',
#  'Peaches',
#  'Leave The Door Open',
#  'Motley Crew',
#  'Rapstar',
#  'Astronaut In The Ocean',
#  'Whole Lotta Money',
#  'Blinding Lights',
#  'Heartbreak Anniversary',
#  'You Right',
#  'Without You',
#  'Fancy Like',
#  'Forever After All',
#  'Every Chance I Get',
#  'Famous Friends',
#  'Thot Shit',
#  'Beautiful Mistakes',
#  'Single Saturday Night',
#  'Leave Before You Love Me',
#  'Lil Bit',
#  'Blame It On You',
#  'Glad You Exist',
#  'Best Friend',
#  'Late At Night',
#  "Ain't Shit",
#  'Heat Waves',
#  'Telepatia',
#  'Wants And Needs',
#  'Yonaguni',
#  'NDA',
#  "Drinkin' Beer. Talkin' God. Amen.",
#  "Beggin'",
#  'Drivers License',
#  'Mood',
#  "My Ex's Best Friend",
#  'Traitor',
#  'Wockesha',
#  'Todo de Ti',
#  'pov',
#  'Calling My Phone',
#  'Memory',
# ...

# %%
artist=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
for i in artist:
    if i.text is None:
        Artist_name.append('--')
    else:
        Artist_name.append(i.text)

# %%
Artist_name
# Out:
# ['BTS',
#  'Olivia Rodrigo',
#  'The Kid LAROI & Justin Bieber',
#  'Dua Lipa Featuring DaBaby',
#  'Doja Cat Featuring SZA',
#  'Ed Sheeran',
#  'BTS',
#  'Lil Nas X',
#  'The Weeknd & Ariana Grande',
#  'Olivia Rodrigo',
#  'Justin Bieber Featuring Daniel Caesar & Giveon',
#  'Silk Sonic (Bruno Mars & Anderson .Paak)',
#  'Post Malone',
#  'Polo G',
#  'Masked Wolf',
#  'BIA Featuring Nicki Minaj',
#  'The Weeknd',
#  'Giveon',
#  'Doja Cat & The Weeknd',
#  'The Kid LAROI',
#  'Walker Hayes',
#  'Luke Combs',
#  'DJ Khaled Featuring Lil Baby & Lil Durk',
#  'Chris Young + Kane Brown',
#  'Megan Thee Stallion',
#  'Maroon 5 Featuring Megan Thee Stallion',
#  'Cole Swindell',
#  'Marshmello X Jonas Brothers',
#  'Nelly & Florida Georgia Line',
#  'Jason Aldean',
#  'Dan + Shay',
#  'Saweetie Featuring Doja Cat',
#  'Roddy Ricch',
#  'Doja Cat',
#  'Glass Animals',
#  'Kali Uchis',
#  'Drake Featuring Lil Baby',
#  'Bad Bunny',
#  'Billie Eilish',
# ...

# %%
lwrank=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in lwrank:
    if i.text is None:
        Last_week_rank.append('--')
    else:
        Last_week_rank.append(i.text)

# %%
Last_week_rank
# Out:
# ['-',
#  '2',
#  '-',
#  '3',
#  '4',
#  '6',
#  '1',
#  '5',
#  '9',
#  '10',
#  '8',
#  '7',
#  '-',
#  '12',
#  '11',
#  '-',
#  '15',
#  '19',
#  '13',
#  '16',
#  '20',
#  '18',
#  '21',
#  '22',
#  '17',
#  '23',
#  '26',
#  '28',
#  '25',
#  '31',
#  '35',
#  '24',
#  '32',
#  '41',
#  '27',
#  '34',
#  '29',
#  '30',
#  '-',
#  '40',
#  '46',
#  '33',
#  '36',
#  '43',
#  '38',
#  '37',
#  '39',
#  '42',
#  '45',
#  '-',
#  '47',
#  '66',
#  '63',
#  '53',
#  '48',
#  '62',
#  '52',
#  '58',
#  '51',
#  '54',
#  '60',
#  '55',
#  '64',
#  '56',
#  '61',
#  '57',
#  '50',
#  '59',
#  '44',
#  '75',
#  '71',
#  '82',
#  '74',
#  '70',
#  '67',
#  '68',
#  '72',
#  '-',
#  '79',
#  '80',
#  '85',
#  '76',
#  '83',
#  '69',
#  '91',
#  '77',
#  '78',
#  '93',
#  '-',
#  '88',
#  '90',
#  '84',
#  '89',
#  '-',
#  '95',
#  '49',
#  '96',
#  '92',
#  '94',
#  '-']

# %%
prank=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in prank:
    if i.text is None:
        Peak_rank.append('--')
    else:
        Peak_rank.append(i.text)

# %%
Peak_rank
# Out:
# ['1',
#  '1',
#  '3',
#  '2',
#  '3',
#  '5',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '13',
#  '1',
#  '6',
#  '16',
#  '1',
#  '16',
#  '11',
#  '8',
#  '20',
#  '2',
#  '20',
#  '21',
#  '16',
#  '13',
#  '26',
#  '28',
#  '23',
#  '30',
#  '31',
#  '14',
#  '20',
#  '24',
#  '19',
#  '25',
#  '2',
#  '10',
#  '39',
#  '40',
#  '41',
#  '1',
#  '1',
#  '20',
#  '9',
#  '33',
#  '32',
#  '27',
#  '3',
#  '50',
#  '39',
#  '52',
#  '53',
#  '41',
#  '26',
#  '56',
#  '16',
#  '58',
#  '51',
#  '54',
#  '60',
#  '23',
#  '38',
#  '18',
#  '2',
#  '41',
#  '50',
#  '15',
#  '14',
#  '70',
#  '71',
#  '72',
#  '73',
#  '32',
#  '16',
#  '12',
#  '62',
#  '78',
#  '64',
#  '51',
#  '11',
#  '67',
#  '83',
#  '56',
#  '85',
#  '68',
#  '24',
#  '88',
#  '89',
#  '88',
#  '90',
#  '67',
#  '76',
#  '94',
#  '95',
#  '49',
#  '74',
#  '92',
#  '11',
#  '100']

# %%
board=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in board:
    if i.text is None:
        Weeks_on_board.append('--')
    else:
        Weeks_on_board.append(i.text)

# %%
Weeks_on_board
# Out:
# ['1',
#  '9',
#  '1',
#  '41',
#  '14',
#  '3',
#  '8',
#  '16',
#  '31',
#  '15',
#  '17',
#  '19',
#  '1',
#  '14',
#  '22',
#  '1',
#  '84',
#  '22',
#  '3',
#  '32',
#  '4',
#  '38',
#  '11',
#  '16',
#  '5',
#  '19',
#  '11',
#  '8',
#  '17',
#  '12',
#  '23',
#  '27',
#  '6',
#  '3',
#  '26',
#  '21',
#  '19',
#  '6',
#  '1',
#  '7',
#  '3',
#  '27',
#  '49',
#  '48',
#  '8',
#  '12',
#  '7',
#  '19',
#  '22',
#  '1',
#  '4',
#  '31',
#  '12',
#  '18',
#  '18',
#  '11',
#  '8',
#  '14',
#  '9',
#  '12',
#  '5',
#  '9',
#  '5',
#  '13',
#  '9',
#  '3',
#  '3',
#  '8',
#  '3',
#  '4',
#  '11',
#  '2',
#  '4',
#  '20',
#  '6',
#  '8',
#  '5',
#  '1',
#  '6',
#  '6',
#  '16',
#  '10',
#  '2',
#  '9',
#  '2',
#  '15',
#  '8',
#  '4',
#  '1',
#  '3',
#  '2',
#  '14',
#  '5',
#  '1',
#  '2',
#  '2',
#  '5',
#  '4',
#  '10',
#  '1']

# %%
df=pd.DataFrame({'Song_name':name,
'Artist_name':artist,
'Last_week_rank':lwrank,
'Peak_rank':prank,
'Weeks_on_board':board})

# %%
df
# Out:
#                                             Song_name  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# ..                                                ...
# 95  <selenium.webdriver.remote.webelement.WebEleme...
# 96  <selenium.webdriver.remote.webelement.WebEleme...
# 97  <selenium.webdriver.remote.webelement.WebEleme...
# 98  <selenium.webdriver.remote.webelement.WebEleme...
# 99  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                           Artist_name  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %% [markdown]
# # 7.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://www.naukri.com/"
driver.get(url)

# %%
search_job = driver.find_element_by_id("qsb-keyword-sugg")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ebb42101e95f8872bda421e4c952c933", element="9adcf727-0c9d-48af-9691-2d6f79980534")>

# %%
search_job.send_keys('Data science recruiters')

# %%
search_btn = driver.find_element_by_xpath("//button[@class='btn']")
search_btn.click()

# %%
Name=[]
Designation=[]
Company=[]
Skills_they_hire=[]
Location=[]

# %%
name=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in name:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)
Name
# Out:
# ['Data Science(Using ML with R Programming) Intern - DataTrained',
#  'Analytics Data science and IOT Engineer',
#  'Lead Data Science Analyst - Python/Spark',
#  'Business Analyst - Data Science',
#  'Senior Analyst-Data Science',
#  'Manager Data Science',
#  'Data Science Engineer - Machine/Deep Learning Models - R/Python/Scala',
#  'Data science developer',
#  'Data Science Application Developer',
#  'Data Science Engineer',
#  'Data Science Engineer',
#  'Machine Learning & Automation Expert - Data Science',
#  'Analyst-Data Science',
#  'Analyst-Data Science',
#  'Senior Analyst-Data Science',
#  'Senior Analyst-Data Science',
#  'Manager - Data Science',
#  'TECHNICAL SPECIALIST - DATA SCIENCE job opening with a Edtech Startup',
#  'Senior IT Professionals Part-Time: Java, BA, QA, Data Science, DevOps',
#  'Data Science Application Developer']

# %%
desig=driver.find_elements_by_xpath("//ul[@class='tags has-description']")
for i in desig:
    if i.text is None :
        Designation.append("--") 
    else:
        Designation.append(i.text)
Designation
# Out:
# ['Data Science\nR\nTableau\nMachine Learning',
#  'IT Skills\nPython\nTesting\nData Science\nMachine Learning\nCloud\nAWS\nComputer science',
#  'Data Science\nNLP\nData Scientist\nData Management\nNeural Networks\nSpark\nDeep Learning\nPython',
#  'IT Skills\nTesting\nData Science\nGap Analysis\nUse Cases\nBusiness Analyst\nBrd\nFSD',
#  'IT Skills\nData Science\nMachine Learning\nArtificial Intelligence\nBusiness administration\nAnalyst\nPublishing\nArchitecture',
#  'Report generation\nData management\nMachine learning\nData structures\nBusiness modeling\nMobile applications\nData warehousing\nPredictive analytics',
#  'Data Science\nTensorflow\nR\nArtificial Intelligence\nScala\nTime Series Forecasting\nBig Data\nMachine Learning',
#  'Data Science\nR\nHadoop\nNeural Networks\nData Mining\nBusiness Objects\nMachine Learning\nWeb Services',
#  'Business process\nData analysis\nImage processing\ndata science\nConsulting\nData structures\nData processing\nData quality',
# ...

# %%
com=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in com:
    if i.text is None :
        Company.append("--") 
    else:
        Company.append(i.text)
Company
# Out:
# ['Data Trained Education',
#  'Hexaware Technologies Ltd.',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting Pvt. Ltd',
#  'Accenture Solutions Pvt Ltd',
#  'Reliance Jio Infocomm Ltd.',
#  'CarbyneTech India',
#  'Peopleplus Professional Services Pvt. Ltd.',
#  'Accenture Solutions Pvt Ltd',
#  'IBM India Pvt. Limited',
#  'IBM India Pvt. Limited',
#  'GENPACT India Private Limited',
#  'Accenture Solutions Pvt Ltd',
#  'Accenture Solutions Pvt Ltd',
#  'Accenture Solutions Pvt Ltd',
#  'Accenture Solutions Pvt Ltd',
#  'ExecBoardinAsia',
#  'First Meridian Business Services Private Limited',
#  'Brilliant Computech Private Limited',
#  'Accenture Solutions Pvt Ltd',
#  'Data Trained Education',
#  'Hexaware Technologies Ltd.',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting Pvt. Ltd',
#  'Accenture Solutions Pvt Ltd',
#  'Reliance Jio Infocomm Ltd.',
#  'CarbyneTech India',
#  'Peopleplus Professional Services Pvt. Ltd.',
#  'Accenture Solutions Pvt Ltd',
# ...

# %%
skill=driver.find_elements_by_xpath("//div[@class='job-description fs12 grey-text']")
for i in skill:
    if i.text is None :
        Skills_they_hire.append("--") 
    else:
        Skills_they_hire.append(i.text)
Skills_they_hire
# Out:
# ['We are looking for an enthusiastic Data Science Intern who is passionate about pushing ...',
#  'Tableau Developer with 3+ years of experience and good communication skills Responsibil...',
#  'Qualifications - B Tech or MTechKey Requirement for the Position : - At least 2-year de...',
#  'Key Requirement for the Position Requirement Gathering & Traceability understanding in ...',
#  'You will be required to utilize the existing frameworks, standards, patterns to create ...',
#  'Maximum 5 Years above',
#  'Hands-on experience in implementing Deep learning models with textual data/ time series...',
#  'Description: Work with stakeholders to ensure seamless and quality data collection and ...',
#  'Professional Attributes : 1 A team player with ability to take complete ownership of ta...',
#  'Experience in creating and using advanced machine learning algorithms and statistics su...',
#  'Experience in creating and using advanced machine learning algorithms and statistics su...',
# ...

# %%
loc=driver.find_elements_by_xpath("//span[@class='ellipsis fleft fs12 lh16 ']")
for i in loc:
    if i.text is None :
        Location.append("--") 
    else:
        Location.append(i.text)
Location
# Out:
# ['0-1 Yrs',
#  'Not disclosed',
#  'Noida, Bangalore/Bengaluru, Delhi / NCR',
#  '3-7 Yrs',
#  'Not disclosed',
#  'Mumbai',
#  '6-10 Yrs',
#  'Not disclosed',
#  'Gurgaon/Gurugram',
#  '4-6 Yrs',
#  'Not disclosed',
#  'Gurgaon/Gurugram',
#  '5-8 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '5-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '4-8 Yrs',
#  'Not disclosed',
#  'Hyderabad/Secunderabad',
#  '5-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '4-6 Yrs',
#  'Not disclosed',
#  'Hyderabad/Secunderabad',
#  '6-10 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '6-10 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '6-11 Yrs',
#  'Not disclosed',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru',
#  '3-5 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '3-5 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '5-8 Yrs',
#  'Not disclosed',
#  'Mumbai',
#  '5-8 Yrs',
#  'Not disclosed',
#  'Hyderabad/Secunderabad',
#  '5-10 Yrs',
# ...

# %%
a=({"Name":name,
                "Location":loc,
                "Designation":desig,
                "Company":com,
                "Skills_they_hire":skill})

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()

# %%
df.head()
# Out:
#                                                 Name  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# 4  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                             Location  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# 4  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                          Designation  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %% [markdown]
# # 8.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f63cf867f503> in <module>
# ----> 1 driver=webdriver.Chrome("chromedriver.exe")
#       2 time.sleep(3)
#
# NameError: name 'webdriver' is not defined

# %%
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/"
driver.get(url)

# %%
search = driver.find_element_by_xpath("//a[@class='top-bar__item popup__toggle hide-until-desktop js-search-toggle js-toggle-ready']")
search
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-166-52edb5ec5f84> in <module>
# ----> 1 search = driver.find_element_by_xpath("//a[@class='top-bar__item popup__toggle hide-until-desktop js-search-toggle js-toggle-ready']")
#       2 search
#
# ~\anaconda3\New folder\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\New folder\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# ...

# %%
search.send_keys('highest selling novels')

# %%
search_btn = driver.find_element_by_xpath("//svg[@class='top-bar__item__icon__svg inline-search-36__svg inline-icon__svg']")
search_btn.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-162-c2059054dd3b> in <module>
# ----> 1 search_btn = driver.find_element_by_xpath("//svg[@class='top-bar__item__icon__svg inline-search-36__svg inline-icon__svg']")
#       2 search_btn.click()
#
# ~\anaconda3\New folder\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\New folder\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# ...

# %%
Book name
Author name
Volumes sold
Publisher
Genre

# %% [markdown]
# # 9.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
Name=[]
Year_span=[]
Genre=[]
Run_time=[]
Ratings=[]
Votes=[]

# %%
name=driver.find_elements_by_xpath("//h3[@class='lister-item-header']")
for i in name:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)
Name
# Out:
# ['1. Game of Thrones (2011–2019)',
#  '2. Stranger Things (2016– )',
#  '3. The Walking Dead (2010–2022)',
#  '4. 13 Reasons Why (2017–2020)',
#  '5. The 100 (2014–2020)',
#  '6. Orange Is the New Black (2013–2019)',
#  '7. Riverdale (2017– )',
#  "8. Grey's Anatomy (2005– )",
#  '9. The Flash (2014– )',
#  '10. Arrow (2012–2020)',
#  '11. Money Heist (2017–2021)',
#  '12. The Big Bang Theory (2007–2019)',
#  '13. Black Mirror (2011– )',
#  '14. Sherlock (2010–2017)',
#  '15. Vikings (2013–2020)',
#  '16. Pretty Little Liars (2010–2017)',
#  '17. The Vampire Diaries (2009–2017)',
#  '18. American Horror Story (2011– )',
#  '19. Breaking Bad (2008–2013)',
#  '20. Lucifer (2016– )',
#  '21. Supernatural (2005–2020)',
#  '22. Prison Break (2005–2017)',
#  '23. How to Get Away with Murder (2014–2020)',
#  '24. Teen Wolf (2011–2017)',
#  '25. The Simpsons (1989– )',
#  '26. Once Upon a Time (2011–2018)',
#  '27. Narcos (2015–2017)',
#  '28. Daredevil (2015–2018)',
# ...

# %%
span=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in span:
    if i.text is None :
        Year_span.append("--") 
    else:
        Year_span.append(i.text)
Year_span
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017– )',
#  '(2005– )',
#  '(2014– )',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011– )',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016– )',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016– )',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2021)',
#  '(2015– )',
#  '(1999–2022)',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013– )',
#  '(2004–2012)',
# ...

# %%
genre=driver.find_elements_by_xpath("//span[@class='genre']")
for i in genre:
    if i.text is None :
        Genre.append("--") 
    else:
        Genre.append(i.text)
Genre
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Mystery',
#  'Comedy, Romance',
#  'Drama, Sci-Fi, Thriller',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
# ...

# %%
time=driver.find_elements_by_xpath("//span[@class='runtime']")
for i in time:
    if i.text is None :
        Run_time.append("--") 
    else:
        Run_time.append(i.text)
Run_time
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
ratings=driver.find_elements_by_xpath("//span[@class='ipl-rating-star__rating']")
for i in ratings:
    if i.text is None :
        Ratings.append("--") 
    else:
        Ratings.append(i.text)
Ratings
# Out:
# ['9.2',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8.7',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8.2',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7.6',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7.6',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
votes=driver.find_elements_by_xpath("//span[@name='nv']")
for i in votes:
    if i.text is None :
        Votes.append("--") 
    else:
        Votes.append(i.text)
Votes
# Out:
# ['1,837,730',
#  '1,837,730',
#  '876,335',
#  '880,430',
#  '264,448',
#  '225,915',
#  '283,649',
#  '125,246',
#  '264,115',
#  '317,507',
#  '413,591',
#  '338,219',
#  '740,868',
#  '466,561',
#  '835,363',
#  '456,298',
#  '155,319',
#  '292,256',
#  '284,335',
#  '1,541,589',
#  '259,829',
#  '402,162',
#  '490,486',
#  '135,315',
#  '132,174',
#  '373,918',
#  '212,032',
#  '373,375',
#  '373,150',
#  '873,988',
#  '621,605',
#  '372,874',
#  '344,173',
#  '121,988',
#  '114,829',
#  '158,711',
#  '143,491',
#  '215,669',
#  '442,531',
#  '197,207',
#  '374,769',
#  '406,668',
#  '55,831',
#  '156,389',
#  '475,236',
#  '309,856',
#  '58,443',
#  '174,971',
#  '212,245',
#  '199,457',
#  '204,420',
#  '156,088',
#  '661,942',
#  '117,369',
#  '311,282',
#  '211,309',
#  '510,078',
#  '387,981',
#  '424,597',
#  '58,015',
#  '103,991',
#  '321,400',
#  '68,031',
#  '95,270',
#  '192,756',
#  '82,003',
#  '68,775',
#  '41,293',
#  '139,417',
#  '338,644',
#  '246,072',
# ...

# %%
a=({'Name':name,
'Year_span':span,
'Genre':genre,
'Run_time':time,
'Ratings':ratings,
'Votes':votes})

# %%
df=pd.DataFrame.from_dict(a,orient='index')
df= df.transpose()

# %%
df.head(10)
# Out:
#                                                 Name  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# 4  <selenium.webdriver.remote.webelement.WebEleme...
# 5  <selenium.webdriver.remote.webelement.WebEleme...
# 6  <selenium.webdriver.remote.webelement.WebEleme...
# 7  <selenium.webdriver.remote.webelement.WebEleme...
# 8  <selenium.webdriver.remote.webelement.WebEleme...
# 9  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                            Year_span  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# 4  <selenium.webdriver.remote.webelement.WebEleme...
# 5  <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %% [markdown]
# # 10.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://archive.ics.uci.edu/"
driver.get(url)

# %%
search_btn = driver.find_element_by_xpath("//span[@class='whitetext']")
search_btn.click()
